# %%
purchase_amount= int(input("Customer purchases amount:"))
threshold=200000
discount = 0.12
if purchase_amount >200000:
  new_discount= purchase_amount * discount
  new_purchaseAmount= purchase_amount - new_discount  #this is not bonus, this is discount
  print(f"Discount applied is: Rs.{new_discount}")
  print(f"After discount amount is: Rs.{new_purchaseAmount}")
else:
  print(f"no exceeded so purchase amount is: Rs.{purchase_amount}")
# Out:
# Customer purchases amount:210000
# Discount aaplied is: Rs.25200.0
# After discount amount is: Rs.184800.0
